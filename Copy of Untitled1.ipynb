# %%
print("hello world")
# Out:
# hello world

# %%
a=52
b=21
c=a+b
print("sum of the ",c)
# Out:
# sum of the  73

# %%
a=int(input("enter first no:"))
b=int(input("enter second no:"))
c=a*b
print("result=",c)
# Out:
# enter first no:99
# enter second no:23
# result= 2277
